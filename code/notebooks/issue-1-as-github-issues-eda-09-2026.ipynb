# %% [markdown]
# ### This notebook aims to just do some preliminary exploration on the GitHub issues data that we extracted on `06-09-2026`

# %%
# !pip install pandas matplotlib seaborn --quiet
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 120
sns.set_style('white')

# %%
DATA_DIR = "..\..\data"

# %%
df = pd.read_csv(fr"{DATA_DIR}\interim\issues.csv")
df.shape
# Out:
# (120, 4)

# %%
df
# Out:
#                   repo_name  issue_number  \
# 0                  journals            17
# 1                  journals            12
# 2                 portfolio           135
# 3                 portfolio           134
# 4                 portfolio           133
# ..                      ...           ...
# 115   customer-satisfaction             8
# 116                ResuMaze             4
# 117              ThreadRace             3
# 118  monte-carlo-simulation             3
# 119            AsiFunctions             9
#
#                                              title  \
# 0     add a copy button for any code snippet block
# 1                       implement SEO. AEO and GEO
# 2          Code snippet for public commits per day
# 3    consolidate project section and project pages
# 4           project journaling routine development
# ..                                             ...
# 115                                     deployment
# ...

# %%
# How many unique repositories do I have with issues?
df['repo_name'].nunique()
# Out:
# 46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   repo_name     120 non-null    object
#  1   issue_number  120 non-null    int64
#  2   title         120 non-null    object
#  3   labels        69 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.9+ KB
